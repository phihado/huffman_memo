# %%
txt = open("Huffman.rtf").read()

# %%
from collections import Counter

# %%
wordcount = Counter(txt.split())

# %%
for item in wordcount.items(): print("{}\t{}".format(*item))
# Out:
# (Table	10
# doses:	1
# four	10
# parked.\	1
# Does	1
# self-reliant	1
# Until	1
# Foundation	6
# 161.;	1
# granting	1
# habitual.	1
# writing\	1
# adaptable	1
# lency	1
# Cases	1
# Sentencing\	1
# better.	1
# Weeks\	1
# deli	1
# 1478125	1
# advice.	1
# advice,	3
# advice;	1
# bringing	2
# writing.	1
# Less	2
# Case"	1
# protest	1
# govern?\	1
# Desperate	4
# Paul	1
# charter	1
# her.	15
# her,	6
# second	8
# 11-28-2001	1
# her?	1
# admitted,	1
# Honorable	14
# ?afford[s]\	1
# quite	1
# report;	1
# stars	1
# contributed	2
# sales.	1
# Imposed2	1
# Hamilton	1
# Imposed7	1
# wellbeing,	1
# reasons\	1
# contributes	3
# so.\	1
# kid.	1
# presentence	1
# successes.	1
# 2012),	2
# here	11
# reported	2
# GRE	2
# cart	1
# Document-4256	1
# Document-4252	1
# calculate	1
# kids	10
# IX,	1
# Test?Taking	1
# reports	1
# im?\	1
# costar-s.?	1
# woman?s	1
# her\	27
# Alternative	7
# Offenses.	1
# a.\	1
# "FiledTJ9/06/19	1
# 1399900	1
# appropriately	1
# ground	1
# brought	14
# one?s\	1
# Basic	1
# ...

# %%
wordcount.most_common()
# Out:
# [('\\', 3174),
#  ('the', 1133),
#  ('to', 979),
#  ('and', 977),
#  ('of', 804),
#  ('a', 653),
#  ('I', 496),
#  ('in', 493),
#  ('her', 435),
#  ('was', 404),
#  ('for', 346),
#  ('that', 337),
#  ('with', 320),
#  ('she', 313),
#  ('Felicity', 268),
#  ('my', 240),
#  ('is', 210),
#  ('as', 199),
#  ('on', 194),
#  ('Ms.', 190),
#  ('me', 175),
#  ('at', 156),
#  ('18', 156),
#  ('Huffman', 149),
#  ('this', 145),
#  ('had', 143),
#  ('has', 141),
#  ('She', 136),
#  ('not', 133),
#  ('The', 133),
#  ('Page', 132),
#  ('have', 127),
#  ('USC', 126),
#  ('be', 123),
#  ('it', 119),
#  ('Case', 118),
#  ('an', 114),
#  ('who', 114),
#  ('or', 111),
#  ('mo.', 109),
#  ('States', 109),
#  ('Filed', 108),
#  ('09/06/19', 106),
#  ('United', 105),
#  ('Document', 104),
#  ('we', 100),
#  ('1:19-cr-10117-IT', 99),
#  ('would', 99),
#  ('0', 97),
#  ('from', 97),
#  ('Probation\\', 91),
#  ('Id.', 90),
#  ('about', 90),
#  ('our', 90),
#  ('were', 87),
#  ('4', 87),
#  ('their', 87),
# ...
